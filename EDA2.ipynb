# %%
import requests
import json
import pandas as pd
import seaborn as sns
import matplotlib as plt
import time
import numpy as np

# %%
path = r'C:\Users\progr\OneDrive\Desktop\Project_Statbotics\full_table2.csv'

df = pd.read_csv(path)

# %%
df
# Out:
#          actual_time comp_level event_key             key  match_number  \
# 0       1.742056e+09          f  2025alhu   2025alhu_f1m1             1
# 1       1.742058e+09          f  2025alhu   2025alhu_f1m2             2
# 2       1.741960e+09         qm  2025alhu    2025alhu_qm1             1
# 3       1.741965e+09         qm  2025alhu   2025alhu_qm10            10
# 4       1.741965e+09         qm  2025alhu   2025alhu_qm11            11
# ...              ...        ...       ...             ...           ...
# 111439  1.749930e+09         sf  2025wiwi  2025wiwi_sf5m1             1
# 111440  1.749931e+09         sf  2025wiwi  2025wiwi_sf6m1             1
# 111441  1.749931e+09         sf  2025wiwi  2025wiwi_sf7m1             1
# 111442  1.749932e+09         sf  2025wiwi  2025wiwi_sf8m1             1
# 111443  1.749933e+09         sf  2025wiwi  2025wiwi_sf9m1             1
#
#         post_result_time  set_number        time  \
# 0           1.742056e+09           1  1742055840
# 1           1.742058e+09           1  1742057100
# 2           1.741960e+09           1  1741960200
# 3           1.741965e+09           1  1741965000
# 4           1.741965e+09           1  1741965480
# ...                  ...         ...         ...
# 111439      1.749930e+09           5  1749928800
# 111440      1.749931e+09           6  1749929400
# 111441      1.749931e+09           7  1749930000
# 111442      1.749932e+09           8  1749930600
# 111443      1.749933e+09           9  1749931200
#
#                                              videos winning_alliance  ...  \
# 0       [{'key': 'NSWVoO4ZDEs', 'type': 'youtube'}]             blue  ...
# 1       [{'key': '1FpcfKgS3kw', 'type': 'youtube'}]             blue  ...
# 2       [{'key': 'mAbsfvQlhaw', 'type': 'youtube'}]              red  ...
# 3       [{'key': 'xrkAU-qZY-E', 'type': 'youtube'}]              red  ...
# 4       [{'key': 'ae-lJ4geVPg', 'type': 'youtube'}]             blue  ...
# ...                                             ...              ...  ...
# 111439  [{'key': 'tsHBY8tak-Y', 'type': 'youtube'}]             blue  ...
# 111440  [{'key': 'jhFDvgGOHh0', 'type': 'youtube'}]             blue  ...
# 111441  [{'key': 'gs12RD28JaU', 'type': 'youtube'}]              red  ...
# 111442  [{'key': 'R2HdxFi6Pko', 'type': 'youtube'}]             blue  ...
# 111443  [{'key': '4EDH-FVSSak', 'type': 'youtube'}]             blue  ...
#
#         teleopReef_topRow_nodeH  teleopReef_topRow_nodeI  \
# 0                          True                     True
# 1                          True                     True
# 2                         False                    False
# 3                          True                     True
# 4                         False                    False
# ...                         ...                      ...
# 111439                    False                    False
# 111440                    False                    False
# 111441                     True                     True
# 111442                     True                     True
# 111443                     True                    False
#
#         teleopReef_topRow_nodeJ  teleopReef_topRow_nodeK  \
# 0                         False                    False
# 1                          True                     True
# 2                         False                    False
# 3                          True                     True
# 4                          True                     True
# ...                         ...                      ...
# 111439                    False                    False
# 111440                    False                    False
# 111441                     True                     True
# 111442                     True                     True
# 111443                     True                     True
#
#         teleopReef_topRow_nodeL  teleopReef_trough wallAlgaeCount  \
# 0                          True                0.0            0.0
# 1                         False                0.0            0.0
# 2                         False                5.0            2.0
# 3                          True                1.0            0.0
# 4                          True                1.0            1.0
# ...                         ...                ...            ...
# 111439                    False                0.0            0.0
# 111440                     True                2.0            3.0
# 111441                     True                5.0            0.0
# 111442                     True                0.0            2.0
# 111443                     True                3.0            4.0
#
#         team_number  scorePenaltyFree  alliance
# 0           frc2783             124.0       red
# 1           frc2783             144.0       red
# 2           frc5045             129.0       red
# 3            frc538             112.0       red
# 4           frc6107              61.0       red
# ...             ...               ...       ...
# 111439       frc155               1.0      blue
# 111440       frc230              90.0      blue
# 111441      frc8085             101.0      blue
# 111442      frc7869             135.0      blue
# 111443       frc230             128.0      blue
#
# [111444 rows x 120 columns]

# %%
sns.histplot(data = df, x = 'scorePenaltyFree', kde = True)
# Out:
# <Axes: xlabel='scorePenaltyFree', ylabel='Count'>

# %%
sns.countplot(data = df, x = 'alliance').bar_label(sns.countplot(x='alliance', data=df).containers[0])
# Out:
# [Text(0, 0, '55722'), Text(0, 0, '55722')]

# %%
sns.histplot(data = df, x = 'algaePoints', kde = True)
# Out:
# <Axes: xlabel='algaePoints', ylabel='Count'>

# %%
sns.histplot(data = df, x = 'autoPoints', kde = True)
# Out:
# <Axes: xlabel='autoPoints', ylabel='Count'>

# %%
sns.histplot(data = df, x = 'autoPoints', kde = True, bins = 23)
# Out:
# <Axes: xlabel='autoPoints', ylabel='Count'>

# %%
pd.set_option('display.max_info_columns', 240)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111444 entries, 0 to 111443
# Data columns (total 120 columns):
#  #    Column                      Non-Null Count   Dtype
# ---   ------                      --------------   -----
#  0    actual_time                 111444 non-null  float64
#  1    comp_level                  111444 non-null  object
#  2    event_key                   111444 non-null  object
#  3    key                         111444 non-null  object
#  4    match_number                111444 non-null  int64
#  5    post_result_time            111444 non-null  float64
#  6    set_number                  111444 non-null  int64
#  7    time                        111444 non-null  int64
#  8    videos                      111444 non-null  object
#  9    winning_alliance            111444 non-null  object
#  10   score                       111444 non-null  int64
#  11   adjustPoints                111444 non-null  float64
#  12   algaePoints                 111444 non-null  float64
#  13   autoBonusAchieved           111444 non-null  bool
#  14   autoCoralCount              111444 non-null  float64
#  15   autoCoralPoints             111444 non-null  float64
#  16   autoLine                    111444 non-null  object
#  17   autoMobilityPoints          111444 non-null  float64
#  18   autoPoints                  111444 non-null  float64
#  19   autoReef_botRow_nodeA       111444 non-null  bool
#  20   autoReef_botRow_nodeB       111444 non-null  bool
#  21   autoReef_botRow_nodeC       111444 non-null  bool
#  22   autoReef_botRow_nodeD       111444 non-null  bool
#  23   autoReef_botRow_nodeE       111444 non-null  bool
#  24   autoReef_botRow_nodeF       111444 non-null  bool
#  25   autoReef_botRow_nodeG       111444 non-null  bool
#  26   autoReef_botRow_nodeH       111444 non-null  bool
#  27   autoReef_botRow_nodeI       111444 non-null  bool
#  28   autoReef_botRow_nodeJ       111444 non-null  bool
#  29   autoReef_botRow_nodeK       111444 non-null  bool
#  30   autoReef_botRow_nodeL       111444 non-null  bool
#  31   autoReef_midRow_nodeA       111444 non-null  bool
#  32   autoReef_midRow_nodeB       111444 non-null  bool
#  33   autoReef_midRow_nodeC       111444 non-null  bool
#  34   autoReef_midRow_nodeD       111444 non-null  bool
#  35   autoReef_midRow_nodeE       111444 non-null  bool
#  36   autoReef_midRow_nodeF       111444 non-null  bool
#  37   autoReef_midRow_nodeG       111444 non-null  bool
#  38   autoReef_midRow_nodeH       111444 non-null  bool
#  39   autoReef_midRow_nodeI       111444 non-null  bool
#  40   autoReef_midRow_nodeJ       111444 non-null  bool
#  41   autoReef_midRow_nodeK       111444 non-null  bool
#  42   autoReef_midRow_nodeL       111444 non-null  bool
#  43   autoReef_tba_botRowCount    111444 non-null  float64
#  44   autoReef_tba_midRowCount    111444 non-null  float64
#  45   autoReef_tba_topRowCount    111444 non-null  float64
#  46   autoReef_topRow_nodeA       111444 non-null  bool
#  47   autoReef_topRow_nodeB       111444 non-null  bool
#  48   autoReef_topRow_nodeC       111444 non-null  bool
#  49   autoReef_topRow_nodeD       111444 non-null  bool
#  50   autoReef_topRow_nodeE       111444 non-null  bool
#  51   autoReef_topRow_nodeF       111444 non-null  bool
#  52   autoReef_topRow_nodeG       111444 non-null  bool
#  53   autoReef_topRow_nodeH       111444 non-null  bool
#  54   autoReef_topRow_nodeI       111444 non-null  bool
#  55   autoReef_topRow_nodeJ       111444 non-null  bool
#  56   autoReef_topRow_nodeK       111444 non-null  bool
#  57   autoReef_topRow_nodeL       111444 non-null  bool
#  58   autoReef_trough             111444 non-null  float64
#  59   bargeBonusAchieved          111444 non-null  bool
#  60   coopertitionCriteriaMet     111444 non-null  bool
#  61   coralBonusAchieved          111444 non-null  bool
#  62   endGameBargePoints          111444 non-null  float64
#  63   endGame                     111444 non-null  object
#  64   foulCount                   111444 non-null  float64
#  65   foulPoints                  111444 non-null  float64
#  66   g206Penalty                 111444 non-null  bool
#  67   g410Penalty                 111444 non-null  bool
#  68   g418Penalty                 111444 non-null  bool
#  69   g428Penalty                 111444 non-null  bool
#  70   netAlgaeCount               111444 non-null  float64
#  71   rp                          111444 non-null  float64
#  72   techFoulCount               111444 non-null  float64
#  73   teleopCoralCount            111444 non-null  float64
#  74   teleopCoralPoints           111444 non-null  float64
#  75   teleopPoints                111444 non-null  float64
#  76   teleopReef_botRow_nodeA     111444 non-null  bool
#  77   teleopReef_botRow_nodeB     111444 non-null  bool
#  78   teleopReef_botRow_nodeC     111444 non-null  bool
#  79   teleopReef_botRow_nodeD     111444 non-null  bool
#  80   teleopReef_botRow_nodeE     111444 non-null  bool
#  81   teleopReef_botRow_nodeF     111444 non-null  bool
#  82   teleopReef_botRow_nodeG     111444 non-null  bool
#  83   teleopReef_botRow_nodeH     111444 non-null  bool
#  84   teleopReef_botRow_nodeI     111444 non-null  bool
#  85   teleopReef_botRow_nodeJ     111444 non-null  bool
#  86   teleopReef_botRow_nodeK     111444 non-null  bool
#  87   teleopReef_botRow_nodeL     111444 non-null  bool
#  88   teleopReef_midRow_nodeA     111444 non-null  bool
#  89   teleopReef_midRow_nodeB     111444 non-null  bool
#  90   teleopReef_midRow_nodeC     111444 non-null  bool
#  91   teleopReef_midRow_nodeD     111444 non-null  bool
#  92   teleopReef_midRow_nodeE     111444 non-null  bool
#  93   teleopReef_midRow_nodeF     111444 non-null  bool
#  94   teleopReef_midRow_nodeG     111444 non-null  bool
#  95   teleopReef_midRow_nodeH     111444 non-null  bool
#  96   teleopReef_midRow_nodeI     111444 non-null  bool
#  97   teleopReef_midRow_nodeJ     111444 non-null  bool
#  98   teleopReef_midRow_nodeK     111444 non-null  bool
#  99   teleopReef_midRow_nodeL     111444 non-null  bool
#  100  teleopReef_tba_botRowCount  111444 non-null  float64
#  101  teleopReef_tba_midRowCount  111444 non-null  float64
#  102  teleopReef_tba_topRowCount  111444 non-null  float64
#  103  teleopReef_topRow_nodeA     111444 non-null  bool
#  104  teleopReef_topRow_nodeB     111444 non-null  bool
#  105  teleopReef_topRow_nodeC     111444 non-null  bool
#  106  teleopReef_topRow_nodeD     111444 non-null  bool
#  107  teleopReef_topRow_nodeE     111444 non-null  bool
#  108  teleopReef_topRow_nodeF     111444 non-null  bool
#  109  teleopReef_topRow_nodeG     111444 non-null  bool
#  110  teleopReef_topRow_nodeH     111444 non-null  bool
#  111  teleopReef_topRow_nodeI     111444 non-null  bool
#  112  teleopReef_topRow_nodeJ     111444 non-null  bool
#  113  teleopReef_topRow_nodeK     111444 non-null  bool
#  114  teleopReef_topRow_nodeL     111444 non-null  bool
#  115  teleopReef_trough           111444 non-null  float64
#  116  wallAlgaeCount              111444 non-null  float64
#  117  team_number                 111444 non-null  object
#  118  scorePenaltyFree            111444 non-null  float64
#  119  alliance                    111444 non-null  object
# dtypes: bool(80), float64(27), int64(4), object(9)
# memory usage: 42.5+ MB

# %%
df
# Out:
#          actual_time comp_level event_key             key  match_number  \
# 0       1.742056e+09          f  2025alhu   2025alhu_f1m1             1
# 1       1.742058e+09          f  2025alhu   2025alhu_f1m2             2
# 2       1.741960e+09         qm  2025alhu    2025alhu_qm1             1
# 3       1.741965e+09         qm  2025alhu   2025alhu_qm10            10
# 4       1.741965e+09         qm  2025alhu   2025alhu_qm11            11
# ...              ...        ...       ...             ...           ...
# 111439  1.749930e+09         sf  2025wiwi  2025wiwi_sf5m1             1
# 111440  1.749931e+09         sf  2025wiwi  2025wiwi_sf6m1             1
# 111441  1.749931e+09         sf  2025wiwi  2025wiwi_sf7m1             1
# 111442  1.749932e+09         sf  2025wiwi  2025wiwi_sf8m1             1
# 111443  1.749933e+09         sf  2025wiwi  2025wiwi_sf9m1             1
#
#         post_result_time  set_number        time  \
# 0           1.742056e+09           1  1742055840
# 1           1.742058e+09           1  1742057100
# 2           1.741960e+09           1  1741960200
# 3           1.741965e+09           1  1741965000
# 4           1.741965e+09           1  1741965480
# ...                  ...         ...         ...
# 111439      1.749930e+09           5  1749928800
# 111440      1.749931e+09           6  1749929400
# 111441      1.749931e+09           7  1749930000
# 111442      1.749932e+09           8  1749930600
# 111443      1.749933e+09           9  1749931200
#
#                                              videos winning_alliance  ...  \
# 0       [{'key': 'NSWVoO4ZDEs', 'type': 'youtube'}]             blue  ...
# 1       [{'key': '1FpcfKgS3kw', 'type': 'youtube'}]             blue  ...
# 2       [{'key': 'mAbsfvQlhaw', 'type': 'youtube'}]              red  ...
# 3       [{'key': 'xrkAU-qZY-E', 'type': 'youtube'}]              red  ...
# 4       [{'key': 'ae-lJ4geVPg', 'type': 'youtube'}]             blue  ...
# ...                                             ...              ...  ...
# 111439  [{'key': 'tsHBY8tak-Y', 'type': 'youtube'}]             blue  ...
# 111440  [{'key': 'jhFDvgGOHh0', 'type': 'youtube'}]             blue  ...
# 111441  [{'key': 'gs12RD28JaU', 'type': 'youtube'}]              red  ...
# 111442  [{'key': 'R2HdxFi6Pko', 'type': 'youtube'}]             blue  ...
# 111443  [{'key': '4EDH-FVSSak', 'type': 'youtube'}]             blue  ...
#
#         teleopReef_topRow_nodeH  teleopReef_topRow_nodeI  \
# 0                          True                     True
# 1                          True                     True
# 2                         False                    False
# 3                          True                     True
# 4                         False                    False
# ...                         ...                      ...
# 111439                    False                    False
# 111440                    False                    False
# 111441                     True                     True
# 111442                     True                     True
# 111443                     True                    False
#
#         teleopReef_topRow_nodeJ  teleopReef_topRow_nodeK  \
# 0                         False                    False
# 1                          True                     True
# 2                         False                    False
# 3                          True                     True
# 4                          True                     True
# ...                         ...                      ...
# 111439                    False                    False
# 111440                    False                    False
# 111441                     True                     True
# 111442                     True                     True
# 111443                     True                     True
#
#         teleopReef_topRow_nodeL  teleopReef_trough wallAlgaeCount  \
# 0                          True                0.0            0.0
# 1                         False                0.0            0.0
# 2                         False                5.0            2.0
# 3                          True                1.0            0.0
# 4                          True                1.0            1.0
# ...                         ...                ...            ...
# 111439                    False                0.0            0.0
# 111440                     True                2.0            3.0
# 111441                     True                5.0            0.0
# 111442                     True                0.0            2.0
# 111443                     True                3.0            4.0
#
#         team_number  scorePenaltyFree  alliance
# 0           frc2783             124.0       red
# 1           frc2783             144.0       red
# 2           frc5045             129.0       red
# 3            frc538             112.0       red
# 4           frc6107              61.0       red
# ...             ...               ...       ...
# 111439       frc155               1.0      blue
# 111440       frc230              90.0      blue
# 111441      frc8085             101.0      blue
# 111442      frc7869             135.0      blue
# 111443       frc230             128.0      blue
#
# [111444 rows x 120 columns]
