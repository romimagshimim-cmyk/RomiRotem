# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# %%
path = r'C:\Users\Magsihim_AI\Desktop\Project_Statbotics\actions_data\datasets\actions_df.csv'

df = pd.read_csv(path)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# correlations with target
correlations = df.corr(numeric_only=True)["win"].drop("win")  # drop self-correlation
corr_df = correlations.to_frame().reset_index()
corr_df.columns = ["Feature", "Correlation"]

# sort by absolute correlation
corr_df = corr_df.reindex(corr_df["Correlation"].abs().sort_values(ascending=False).index)

plt.figure(figsize=(8, len(corr_df) * 0.3))
sns.barplot(
    data=corr_df,
    y="Feature", x="Correlation",
    palette="coolwarm"
)
plt.axvline(0, color="black", linewidth=0.8)
plt.title("Feature Correlations with Target", fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Magsihim_AI\AppData\Local\Temp\ipykernel_20340\829829940.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
# correlations with target
correlations = df.corr(numeric_only=True)["score"].drop("score")  # drop self-correlation
corr_df = correlations.to_frame().reset_index()
corr_df.columns = ["Feature", "Correlation"]

# sort by absolute correlation
corr_df = corr_df.reindex(corr_df["Correlation"].abs().sort_values(ascending=False).index)

plt.figure(figsize=(8, len(corr_df) * 0.3))
sns.barplot(
    data=corr_df,
    y="Feature", x="Correlation",
    palette="coolwarm"
)
plt.axvline(0, color="black", linewidth=0.8)
plt.title("Feature Correlations with Target", fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Magsihim_AI\AppData\Local\Temp\ipykernel_20340\2387488131.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
bool_cols = df.select_dtypes(include=["bool", "boolean"]).columns

df[bool_cols].mean().sort_values(ascending=False)
# Out:
# autoLine                   0.925078
# teleopReef_topRow_nodeB    0.716889
# teleopReef_topRow_nodeA    0.716889
# teleopReef_topRow_nodeL    0.681898
# teleopReef_topRow_nodeC    0.678068
#                              ...
# autoReef_botRow_nodeD      0.000918
# autoReef_botRow_nodeC      0.000866
# autoReef_botRow_nodeL      0.000603
# autoReef_botRow_nodeH      0.000367
# autoReef_botRow_nodeG      0.000079
# Length: 74, dtype: float64

# %%
bool_cols = df.select_dtypes(include=["bool", "boolean"]).columns
(df[bool_cols].mean()
 .sort_values(ascending=False)
 .plot(kind="bar", figsize=(12,6)))
plt.ylabel("True")
plt.show()

# %%
df.loc[df['autoReef_botRow_nodeG']]
# Out:
#         score  autoLine  autoReef_botRow_nodeA  autoReef_botRow_nodeB  \
# 63972     102      True                  False                  False
# 66917     139      True                  False                  False
# 70021     137      True                  False                  False
# 83027     102      True                  False                  False
# 85974     139      True                  False                  False
# 89083     137      True                  False                  False
# 102087    102      True                  False                  False
# 105036    139      True                  False                  False
# 108144    137      True                  False                  False
#
#         autoReef_botRow_nodeC  autoReef_botRow_nodeD  autoReef_botRow_nodeE  \
# 63972                   False                  False                  False
# 66917                   False                  False                  False
# ...

# %%
df['win'].mean()
# Out:
# 0.4964589235127479

# %%
df['teleopReef_topRow_nodeG'].mean()
# Out:
# 0.5011278984366803

# %%
df_nums = df.select_dtypes(exclude='bool')

# %%
df_nums
# Out:
#         score  autoReef_trough  endGame  foulCount  netAlgaeCount  \
# 0         124              0.0        1        0.0            8.0
# 1         144              0.0        3        0.0            7.0
# 2         129              0.0        0        0.0            4.0
# 3         118              0.0        1        0.0            2.0
# 4          67              1.0        1        1.0            2.0
# ...       ...              ...      ...        ...            ...
# 114367     64              1.0        1        0.0            0.0
# 114368     72              0.0        0        0.0            0.0
# 114369     77              1.0        1        1.0            8.0
# 114370     79              1.0        1        1.0            0.0
# 114371     61              0.0        1        0.0            0.0
#
#         techFoulCount  teleopReef_trough  wallAlgaeCount  team_number  \
# 0                 0.0                0.0             0.0         2783
# ...

# %% [markdown]
# numeric columns EDA

# %%
sns.heatmap(df_nums.corr(), cmap="coolwarm", vmin=-1)
plt.show()

# %%
sns.histplot(data = df['score'], kde = True)
# Out:
# <Axes: xlabel='score', ylabel='Count'>

# %%
sns.boxenplot(data = df, x = 'score')
# Out:
# <Axes: xlabel='score'>

# %%
sns.countplot(data = df, x = 'autoReef_trough').bar_label(sns.countplot(x='autoReef_trough', data=df).containers[0])
# Out:
# [Text(0, 0, '78697'),
#  Text(0, 0, '29285'),
#  Text(0, 0, '5316'),
#  Text(0, 0, '921'),
#  Text(0, 0, '135'),
#  Text(0, 0, '18')]

# %%
sns.boxenplot(data = df, x = 'autoReef_trough')
# Out:
# <Axes: xlabel='autoReef_trough'>

# %%
df.loc[df['autoReef_trough'] == 5]
# Out:
#         score  autoLine  autoReef_botRow_nodeA  autoReef_botRow_nodeB  \
# 1839      131      True                  False                  False
# 3400       61      True                   True                   True
# 5774      102      True                  False                  False
# 20909     131      True                  False                  False
# 22470      61     False                   True                   True
# 24844     102      True                  False                  False
# 39968     131      True                  False                  False
# 41529      61      True                   True                   True
# 43903     102      True                  False                  False
# 67475     145      True                  False                  False
# 73000      50      True                  False                  False
# 75381      72      True                  False                  False
# ...

# %%
sns.countplot(data = df, x = 'endGame').bar_label(sns.countplot(x='endGame', data=df).containers[0])
# Out:
# [Text(0, 0, '27069'),
#  Text(0, 0, '61171'),
#  Text(0, 0, '735'),
#  Text(0, 0, '25397')]

# %%
sns.histplot(data = df['foulCount'], kde = True)
# Out:
# <Axes: xlabel='foulCount', ylabel='Count'>

# %%
sns.countplot(data = df, x = 'foulCount').bar_label(sns.countplot(x='foulCount', data=df).containers[0])
# Out:
# [Text(0, 0, '95007'),
#  Text(0, 0, '14737'),
#  Text(0, 0, '3107'),
#  Text(0, 0, '906'),
#  Text(0, 0, '336'),
#  Text(0, 0, '123'),
#  Text(0, 0, '96'),
#  Text(0, 0, '36'),
#  Text(0, 0, '15'),
#  Text(0, 0, '6'),
#  Text(0, 0, '3')]

# %%
sns.histplot(data = df['netAlgaeCount'], kde = True, bins = 19)
# Out:
# <Axes: xlabel='netAlgaeCount', ylabel='Count'>

# %%
plt.figure(figsize=(8, 4))
ax = sns.countplot(x='netAlgaeCount', data=df, width=0.6)
ax.bar_label(ax.containers[0])
plt.tight_layout()
plt.show()

# %%
sns.regplot(data = df, x = 'netAlgaeCount', y = 'score')
# Out:
# <Axes: xlabel='netAlgaeCount', ylabel='score'>

# %%
df_nums
# Out:
#         score  autoReef_trough  endGame  foulCount  netAlgaeCount  \
# 0         124              0.0        1        0.0            8.0
# 1         144              0.0        3        0.0            7.0
# 2         129              0.0        0        0.0            4.0
# 3         118              0.0        1        0.0            2.0
# 4          67              1.0        1        1.0            2.0
# ...       ...              ...      ...        ...            ...
# 114367     64              1.0        1        0.0            0.0
# 114368     72              0.0        0        0.0            0.0
# 114369     77              1.0        1        1.0            8.0
# 114370     79              1.0        1        1.0            0.0
# 114371     61              0.0        1        0.0            0.0
#
#         techFoulCount  teleopReef_trough  wallAlgaeCount  team_number  \
# 0                 0.0                0.0             0.0         2783
# ...

# %%
plt.figure(figsize=(10, 4))
ax = sns.countplot(x='techFoulCount', data=df, width=0.6)
ax.bar_label(ax.containers[0])
plt.tight_layout()
plt.show()

# %%
sns.regplot(data = df, x = 'techFoulCount', y = 'foulCount')
# Out:
# <Axes: xlabel='techFoulCount', ylabel='foulCount'>

# %%
df['techFoulCount'].sort_values(ascending=False)
# Out:
# 38475     49.0
# 341       49.0
# 19403     49.0
# 73598     46.0
# 111721    46.0
#           ...
# 55456      0.0
# 55455      0.0
# 16272      0.0
# 55453      0.0
# 0          0.0
# Name: techFoulCount, Length: 114372, dtype: float64

# %%
sns.kdeplot(x = 'teleopReef_trough', data = df)
# Out:
# <Axes: xlabel='teleopReef_trough', ylabel='Density'>

# %%
sns.regplot(data = df, x = 'autoReef_trough', y = 'teleopReef_trough')
# Out:
# <Axes: xlabel='autoReef_trough', ylabel='teleopReef_trough'>

# %%
sns.regplot(data = df, x = 'teleopReef_trough', y = 'score')
# Out:
# <Axes: xlabel='teleopReef_trough', ylabel='score'>

# %%
sns.histplot(data = df['wallAlgaeCount'], kde = True, bins = 13)
# Out:
# <Axes: xlabel='wallAlgaeCount', ylabel='Count'>

# %%
plt.figure(figsize=(8, 4))
ax = sns.countplot(x='wallAlgaeCount', data=df, width=0.6)
ax.bar_label(ax.containers[0])
plt.tight_layout()
plt.show()

# %%
sns.regplot(data = df, x = 'wallAlgaeCount', y = 'score')
# Out:
# <Axes: xlabel='wallAlgaeCount', ylabel='score'>

# %%
sns.regplot(data = df, x = 'wallAlgaeCount', y = 'netAlgaeCount')
# Out:
# <Axes: xlabel='wallAlgaeCount', ylabel='netAlgaeCount'>

# %%
sns.histplot(data = df['team_number'])
# Out:
# <Axes: xlabel='team_number', ylabel='Count'>
