# %%
# !pip install sklearn

# %%
import pandas as pd
import time
from sklearn.model_selection import train_test_split
import seaborn as sns

# %%
start_time = time.time()
path = r'C:\Users\Magsihim_AI\Desktop\Project_Statbotics\data\datasets\final_table.csv'

df = pd.read_csv(path)

# %%
df
# Out:
#         comp_level  event_key  match_number  set_number  score  algaePoints  \
# 0                2          0             1           1    124         32.0
# 1                2          0             2           1    144         28.0
# 2                0          0             1           1    129         28.0
# 3                0          0            10           1    118          8.0
# 4                0          0            11           1     67         14.0
# ...            ...        ...           ...         ...    ...          ...
# 114469           1        228             1           5     64          0.0
# 114470           1        228             1           6     72          0.0
# 114471           1        228             1           7     77         32.0
# 114472           1        228             1           8     79          0.0
# 114473           1        228             1           9     61          0.0
#
# ...

# %%
df = df[df['event_key'] != 0]

# %%
df
# Out:
#         comp_level  event_key  match_number  set_number  score  algaePoints  \
# 96               2          1             1           1    259         32.0
# 97               2          1             2           1    273         36.0
# 98               0          1             1           1    223         38.0
# 99               0          1            10           1    151         28.0
# 100              0          1           100           1    235         56.0
# ...            ...        ...           ...         ...    ...          ...
# 114469           1        228             1           5     64          0.0
# 114470           1        228             1           6     72          0.0
# 114471           1        228             1           7     77         32.0
# 114472           1        228             1           8     79          0.0
# 114473           1        228             1           9     61          0.0
#
# ...

# %%
train, test = train_test_split(df, test_size = 0.25, random_state = 42)

# %%
train.loc[(df['possition'] == 1) & (train['team_number'] == 1574)]
# Out:
#        comp_level  event_key  match_number  set_number  score  algaePoints  \
# 62584           1         61             1           8     87          0.0
# 62567           0         61            64           1    102          0.0
# 5314            0         61             5           1     93         16.0
# 5110            0         59            13           1    196         12.0
# 62593           0         62            14           1     98         12.0
# 62527           0         61            28           1    128          8.0
# 5400            0         62            54           1     96          4.0
# 5338            1         61             1          12     84          0.0
# 62521           0         61            22           1     92         24.0
# 5343            1         61             1           4    127          0.0
# 5379            0         62            35           1    100          0.0
# ...

# %%
def AutoPath(team_number, start_loc):  
    # for i in range (1,4):  
    if start_loc == 3:
            explorauto = train.loc[(train['possition'] == start_loc) & (train['team_number'] == team_number)][['autoReef_trough',
                                    'autoReef_botRow_nodeA', 'autoReef_botRow_nodeB', 'autoReef_botRow_nodeC', 'autoReef_botRow_nodeD', 'autoReef_botRow_nodeE', 'autoReef_botRow_nodeF',
                                    'autoReef_botRow_nodeG',
                                    'autoReef_midRow_nodeA', 'autoReef_midRow_nodeB', 'autoReef_midRow_nodeC', 'autoReef_midRow_nodeD', 'autoReef_midRow_nodeE', 'autoReef_midRow_nodeF',
                                    'autoReef_midRow_nodeG',
                                    'autoReef_topRow_nodeA', 'autoReef_topRow_nodeB', 'autoReef_topRow_nodeC', 'autoReef_topRow_nodeD', 'autoReef_topRow_nodeE', 'autoReef_topRow_nodeF',
                                    'autoReef_topRow_nodeG']]
    elif start_loc == 2:
            explorauto = train.loc[(train['possition'] == start_loc) & (train['team_number'] == team_number)][['autoReef_trough',
                                    'autoReef_botRow_nodeA', 'autoReef_botRow_nodeB', 'autoReef_botRow_nodeC', 'autoReef_botRow_nodeD', 'autoReef_botRow_nodeE', 'autoReef_botRow_nodeF',
                                    'autoReef_botRow_nodeG', 'autoReef_botRow_nodeH', 'autoReef_botRow_nodeI', 'autoReef_botRow_nodeJ', 'autoReef_botRow_nodeK', 'autoReef_botRow_nodeL',
                                    'autoReef_midRow_nodeA', 'autoReef_midRow_nodeB', 'autoReef_midRow_nodeC', 'autoReef_midRow_nodeD', 'autoReef_midRow_nodeE', 'autoReef_midRow_nodeF',
                                    'autoReef_midRow_nodeG', 'autoReef_midRow_nodeH', 'autoReef_midRow_nodeI', 'autoReef_midRow_nodeJ', 'autoReef_midRow_nodeK', 'autoReef_midRow_nodeL',
                                    'autoReef_topRow_nodeA', 'autoReef_topRow_nodeB', 'autoReef_topRow_nodeC', 'autoReef_topRow_nodeD', 'autoReef_topRow_nodeE', 'autoReef_topRow_nodeF',
                                    'autoReef_topRow_nodeG', 'autoReef_topRow_nodeH', 'autoReef_topRow_nodeI', 'autoReef_topRow_nodeJ', 'autoReef_topRow_nodeK', 'autoReef_topRow_nodeL']]
    else:
            explorauto = train.loc[(train['possition'] == start_loc) & (train['team_number'] == team_number)][['autoReef_trough',
                                    'autoReef_botRow_nodeA', 'autoReef_botRow_nodeB', 'autoReef_botRow_nodeH', 'autoReef_botRow_nodeI', 'autoReef_botRow_nodeJ', 'autoReef_botRow_nodeK', 'autoReef_botRow_nodeL',
                                    'autoReef_midRow_nodeA', 'autoReef_midRow_nodeB', 'autoReef_midRow_nodeH', 'autoReef_midRow_nodeI', 'autoReef_midRow_nodeJ', 'autoReef_midRow_nodeK', 'autoReef_midRow_nodeL',
                                    'autoReef_topRow_nodeA', 'autoReef_topRow_nodeB', 'autoReef_topRow_nodeH', 'autoReef_topRow_nodeI', 'autoReef_topRow_nodeJ', 'autoReef_topRow_nodeK', 'autoReef_topRow_nodeL']]
        



    explorauto = explorauto.loc[:, explorauto.any()].astype(int)
    autotrail = dict(explorauto.describe().iloc[1])
    autotrail2 = dict(sorted(autotrail.items(), key=lambda x: x[1], reverse=True))
    return(autotrail2)

# %%
def AutoPathReal(team_number, start_loc):
    # for i in range (1,4):  
    if start_loc == 3:
            explorauto = df.loc[(df['possition'] == start_loc) & (df['team_number'] == team_number)][['autoReef_trough',
                                    'autoReef_botRow_nodeA', 'autoReef_botRow_nodeB', 'autoReef_botRow_nodeC', 'autoReef_botRow_nodeD', 'autoReef_botRow_nodeE', 'autoReef_botRow_nodeF',
                                    'autoReef_botRow_nodeG',
                                    'autoReef_midRow_nodeA', 'autoReef_midRow_nodeB', 'autoReef_midRow_nodeC', 'autoReef_midRow_nodeD', 'autoReef_midRow_nodeE', 'autoReef_midRow_nodeF',
                                    'autoReef_midRow_nodeG',
                                    'autoReef_topRow_nodeA', 'autoReef_topRow_nodeB', 'autoReef_topRow_nodeC', 'autoReef_topRow_nodeD', 'autoReef_topRow_nodeE', 'autoReef_topRow_nodeF',
                                    'autoReef_topRow_nodeG']]
    elif start_loc == 2:
            explorauto = df.loc[(df['possition'] == start_loc) & (df['team_number'] == team_number)][['autoReef_trough',
                                    'autoReef_botRow_nodeA', 'autoReef_botRow_nodeB', 'autoReef_botRow_nodeC', 'autoReef_botRow_nodeD', 'autoReef_botRow_nodeE', 'autoReef_botRow_nodeF',
                                    'autoReef_botRow_nodeG', 'autoReef_botRow_nodeH', 'autoReef_botRow_nodeI', 'autoReef_botRow_nodeJ', 'autoReef_botRow_nodeK', 'autoReef_botRow_nodeL',
                                    'autoReef_midRow_nodeA', 'autoReef_midRow_nodeB', 'autoReef_midRow_nodeC', 'autoReef_midRow_nodeD', 'autoReef_midRow_nodeE', 'autoReef_midRow_nodeF',
                                    'autoReef_midRow_nodeG', 'autoReef_midRow_nodeH', 'autoReef_midRow_nodeI', 'autoReef_midRow_nodeJ', 'autoReef_midRow_nodeK', 'autoReef_midRow_nodeL',
                                    'autoReef_topRow_nodeA', 'autoReef_topRow_nodeB', 'autoReef_topRow_nodeC', 'autoReef_topRow_nodeD', 'autoReef_topRow_nodeE', 'autoReef_topRow_nodeF',
                                    'autoReef_topRow_nodeG', 'autoReef_topRow_nodeH', 'autoReef_topRow_nodeI', 'autoReef_topRow_nodeJ', 'autoReef_topRow_nodeK', 'autoReef_topRow_nodeL']]
    else:
            explorauto = df.loc[(df['possition'] == start_loc) & (df['team_number'] == team_number)][['autoReef_trough',
                                    'autoReef_botRow_nodeA', 'autoReef_botRow_nodeB', 'autoReef_botRow_nodeH', 'autoReef_botRow_nodeI', 'autoReef_botRow_nodeJ', 'autoReef_botRow_nodeK', 'autoReef_botRow_nodeL',
                                    'autoReef_midRow_nodeA', 'autoReef_midRow_nodeB', 'autoReef_midRow_nodeH', 'autoReef_midRow_nodeI', 'autoReef_midRow_nodeJ', 'autoReef_midRow_nodeK', 'autoReef_midRow_nodeL',
                                    'autoReef_topRow_nodeA', 'autoReef_topRow_nodeB', 'autoReef_topRow_nodeH', 'autoReef_topRow_nodeI', 'autoReef_topRow_nodeJ', 'autoReef_topRow_nodeK', 'autoReef_topRow_nodeL']]
        



    explorauto = explorauto.loc[:, explorauto.any()].astype(int)
    autotrail = dict(explorauto.describe().iloc[1])
    autotrail2 = dict(sorted(autotrail.items(), key=lambda x: x[1], reverse=True))
    return(autotrail2)

# %%
#'netAlgaeCount', 'wallAlgaeCount', 'endGame',
def TelePath(team_number, start_loc):
    # for i in range (1,4):  
    explorTele = train.loc[(train['possition'] == start_loc) & (train['team_number'] == team_number)][['teleopReef_trough',
                                    'teleopReef_botRow_nodeA', 'teleopReef_botRow_nodeB', 'teleopReef_botRow_nodeC', 'teleopReef_botRow_nodeD', 'teleopReef_botRow_nodeE', 'teleopReef_botRow_nodeF',
                                    'teleopReef_botRow_nodeG', 'teleopReef_botRow_nodeH', 'teleopReef_botRow_nodeI', 'teleopReef_botRow_nodeJ', 'teleopReef_botRow_nodeK', 'teleopReef_botRow_nodeL',
                                    'teleopReef_midRow_nodeA', 'teleopReef_midRow_nodeB', 'teleopReef_midRow_nodeC', 'teleopReef_midRow_nodeD', 'teleopReef_midRow_nodeE', 'teleopReef_midRow_nodeF',
                                    'teleopReef_midRow_nodeG', 'teleopReef_midRow_nodeH', 'teleopReef_midRow_nodeI', 'teleopReef_midRow_nodeJ', 'teleopReef_midRow_nodeK', 'teleopReef_midRow_nodeL',
                                    'teleopReef_topRow_nodeA', 'teleopReef_topRow_nodeB', 'teleopReef_topRow_nodeC', 'teleopReef_topRow_nodeD', 'teleopReef_topRow_nodeE', 'teleopReef_topRow_nodeF',
                                    'teleopReef_topRow_nodeG', 'teleopReef_topRow_nodeH', 'teleopReef_topRow_nodeI', 'teleopReef_topRow_nodeJ', 'teleopReef_topRow_nodeK', 'teleopReef_topRow_nodeL']]


    explorTele = explorTele.loc[:, explorTele.any()].astype(int)
    TeleTrail = dict(explorTele.describe().iloc[1])
    TeleTrail2 = dict(sorted(TeleTrail.items(), key=lambda x: x[1], reverse=True))
    return(TeleTrail2)

# %%
#'netAlgaeCount', 'wallAlgaeCount', 'endGame',
def TelePathReal(team_number, start_loc):
    # for i in range (1,4):  
    explorTele = df.loc[(df['possition'] == start_loc) & (df['team_number'] == team_number)][['teleopReef_trough',
                                    'teleopReef_botRow_nodeA', 'teleopReef_botRow_nodeB', 'teleopReef_botRow_nodeC', 'teleopReef_botRow_nodeD', 'teleopReef_botRow_nodeE', 'teleopReef_botRow_nodeF',
                                    'teleopReef_botRow_nodeG', 'teleopReef_botRow_nodeH', 'teleopReef_botRow_nodeI', 'teleopReef_botRow_nodeJ', 'teleopReef_botRow_nodeK', 'teleopReef_botRow_nodeL',
                                    'teleopReef_midRow_nodeA', 'teleopReef_midRow_nodeB', 'teleopReef_midRow_nodeC', 'teleopReef_midRow_nodeD', 'teleopReef_midRow_nodeE', 'teleopReef_midRow_nodeF',
                                    'teleopReef_midRow_nodeG', 'teleopReef_midRow_nodeH', 'teleopReef_midRow_nodeI', 'teleopReef_midRow_nodeJ', 'teleopReef_midRow_nodeK', 'teleopReef_midRow_nodeL',
                                    'teleopReef_topRow_nodeA', 'teleopReef_topRow_nodeB', 'teleopReef_topRow_nodeC', 'teleopReef_topRow_nodeD', 'teleopReef_topRow_nodeE', 'teleopReef_topRow_nodeF',
                                    'teleopReef_topRow_nodeG', 'teleopReef_topRow_nodeH', 'teleopReef_topRow_nodeI', 'teleopReef_topRow_nodeJ', 'teleopReef_topRow_nodeK', 'teleopReef_topRow_nodeL']]


    explorTele = explorTele.loc[:, explorTele.any()].astype(int)
    TeleTrail = dict(explorTele.describe().iloc[1])
    TeleTrail2 = dict(sorted(TeleTrail.items(), key=lambda x: x[1], reverse=True))
    return(TeleTrail2)

# %%
def estimate_path(action_dict, threshold = 0.36):
    path = [action for action, freq in action_dict.items() if freq > threshold]
    path.sort(key = lambda a: action_dict[a], reverse = True)
    
    return path

# %%
#Find the best X Auto
scores = []
for i in range(len(test)):
    team, pos = test.iloc[i]['team_number'], test.iloc[i]['possition']
    
    try:
        aestimated_path = AutoPath(team,pos)
    except:
        continue
    if pos == 3:
            actions = test.iloc[i][['autoReef_trough',
                                    'autoReef_botRow_nodeA', 'autoReef_botRow_nodeB', 'autoReef_botRow_nodeC', 'autoReef_botRow_nodeD', 'autoReef_botRow_nodeE', 'autoReef_botRow_nodeF', 'autoReef_botRow_nodeG',
                                    'autoReef_midRow_nodeA', 'autoReef_midRow_nodeB', 'autoReef_midRow_nodeC', 'autoReef_midRow_nodeD', 'autoReef_midRow_nodeE', 'autoReef_midRow_nodeF', 'autoReef_midRow_nodeG',
                                    'autoReef_topRow_nodeA', 'autoReef_topRow_nodeB', 'autoReef_topRow_nodeC', 'autoReef_topRow_nodeD', 'autoReef_topRow_nodeE', 'autoReef_topRow_nodeF', 'autoReef_topRow_nodeG']]
    elif pos == 2:
            actions = test.iloc[i][['autoReef_trough',
                                    'autoReef_botRow_nodeA', 'autoReef_botRow_nodeB', 'autoReef_botRow_nodeC', 'autoReef_botRow_nodeD', 'autoReef_botRow_nodeE', 'autoReef_botRow_nodeF',
                                    'autoReef_botRow_nodeG', 'autoReef_botRow_nodeH', 'autoReef_botRow_nodeI', 'autoReef_botRow_nodeJ', 'autoReef_botRow_nodeK', 'autoReef_botRow_nodeL',
                                    'autoReef_midRow_nodeA', 'autoReef_midRow_nodeB', 'autoReef_midRow_nodeC', 'autoReef_midRow_nodeD', 'autoReef_midRow_nodeE', 'autoReef_midRow_nodeF',
                                    'autoReef_midRow_nodeG', 'autoReef_midRow_nodeH', 'autoReef_midRow_nodeI', 'autoReef_midRow_nodeJ', 'autoReef_midRow_nodeK', 'autoReef_midRow_nodeL',
                                    'autoReef_topRow_nodeA', 'autoReef_topRow_nodeB', 'autoReef_topRow_nodeC', 'autoReef_topRow_nodeD', 'autoReef_topRow_nodeE', 'autoReef_topRow_nodeF',
                                    'autoReef_topRow_nodeG', 'autoReef_topRow_nodeH', 'autoReef_topRow_nodeI', 'autoReef_topRow_nodeJ', 'autoReef_topRow_nodeK', 'autoReef_topRow_nodeL']]
    else:
            actions = test.iloc[i][['autoReef_trough',
                                    'autoReef_botRow_nodeA', 'autoReef_botRow_nodeB', 'autoReef_botRow_nodeH', 'autoReef_botRow_nodeI', 'autoReef_botRow_nodeJ', 'autoReef_botRow_nodeK', 'autoReef_botRow_nodeL',
                                    'autoReef_midRow_nodeA', 'autoReef_midRow_nodeB', 'autoReef_midRow_nodeH', 'autoReef_midRow_nodeI', 'autoReef_midRow_nodeJ', 'autoReef_midRow_nodeK', 'autoReef_midRow_nodeL',
                                    'autoReef_topRow_nodeA', 'autoReef_topRow_nodeB', 'autoReef_topRow_nodeH', 'autoReef_topRow_nodeI', 'autoReef_topRow_nodeJ', 'autoReef_topRow_nodeK', 'autoReef_topRow_nodeL']]
    real_actions = actions[actions == True]
    real_actions = real_actions.keys()
    if len(real_actions) == 0:
        continue
    elif len(list(aestimated_path.keys())) < len(real_actions):
        scores.append(aestimated_path[list(aestimated_path.keys())[-1]])
    else:
        scores.append(aestimated_path[list(aestimated_path.keys())[(len(real_actions))-1]])

# %%
Xauto = (sum(scores)/len(scores))+0.05

# %%
#Find the best X Tele
scores = []
for i in range(len(test)):
    team, pos = test.iloc[i]['team_number'], test.iloc[i]['possition']
    
    try:
        aestimated_path = TelePath(team,pos)
    except:
        continue
    
    actions = test.iloc[i][['teleopReef_trough',
        'teleopReef_botRow_nodeA', 'teleopReef_botRow_nodeB', 'teleopReef_botRow_nodeC', 'teleopReef_botRow_nodeD', 'teleopReef_botRow_nodeE', 'teleopReef_botRow_nodeF',
        'teleopReef_botRow_nodeG', 'teleopReef_botRow_nodeH', 'teleopReef_botRow_nodeI', 'teleopReef_botRow_nodeJ', 'teleopReef_botRow_nodeK', 'teleopReef_botRow_nodeL',
        'teleopReef_midRow_nodeA', 'teleopReef_midRow_nodeB', 'teleopReef_midRow_nodeC', 'teleopReef_midRow_nodeD', 'teleopReef_midRow_nodeE', 'teleopReef_midRow_nodeF',
        'teleopReef_midRow_nodeG', 'teleopReef_midRow_nodeH', 'teleopReef_midRow_nodeI', 'teleopReef_midRow_nodeJ', 'teleopReef_midRow_nodeK', 'teleopReef_midRow_nodeL',
        'teleopReef_topRow_nodeA', 'teleopReef_topRow_nodeB', 'teleopReef_topRow_nodeC', 'teleopReef_topRow_nodeD', 'teleopReef_topRow_nodeE', 'teleopReef_topRow_nodeF',
        'teleopReef_topRow_nodeG', 'teleopReef_topRow_nodeH', 'teleopReef_topRow_nodeI', 'teleopReef_topRow_nodeJ', 'teleopReef_topRow_nodeK', 'teleopReef_topRow_nodeL']]
    real_actions = actions[actions == True]
    real_actions = real_actions.keys()
    if len(real_actions) == 0:
        continue
    elif len(list(aestimated_path.keys())) < len(real_actions):
        scores.append(aestimated_path[list(aestimated_path.keys())[-1]])
    else:
        scores.append(aestimated_path[list(aestimated_path.keys())[(len(real_actions))-1]])

# %%
Xtele = (sum(scores)/len(scores))+0.1

# %%
print(Xauto, Xtele)
# Out:
# 0.48192728466161383 0.6664229757958142

# %%
def simulate(data,func, previos = [[],[],[]]):
    if func == AutoPath or func == AutoPathReal:
        X = Xauto
    elif func == TelePath or func == TelePathReal:
        X = Xtele
    else:
        return 0
    team1 = estimate_path(func(list(data.keys())[0],data[list(data.keys())[0]]), X)
    team2 = estimate_path(func(list(data.keys())[1],data[list(data.keys())[1]]), X)
    team3 = estimate_path(func(list(data.keys())[2],data[list(data.keys())[2]]), X)
    
    if func == AutoPath or func == AutoPathReal:
        team1 = team1[:5]
        team2 = team2[:5]
        team3 = team3[:5]
    
    if set(team1) & set(team2):
        commons = set(team1).intersection(team2)
        for i in commons:
            T1 = (func(list(data.keys())[0],data[list(data.keys())[0]])[i]) + 0.05
            T2 = func(list(data.keys())[1],data[list(data.keys())[1]])[i]
            if (len(team1) > 5) & (len(team1) != len(team2)):
                team1.remove(i)
            elif (len(team2) > 5) & (len(team1) != len(team2)):
                team2.remove(i)
            else:
                if T2>T1:
                    team1.remove(i)
                else:
                    team2.remove(i)
    
    if set(team2) & set(team3):
        commons = set(team2).intersection(team3)
        for i in commons:
            T3 = (func(list(data.keys())[2],data[list(data.keys())[2]])[i]) + 0.05
            T2 = func(list(data.keys())[1],data[list(data.keys())[1]])[i]
            if T2>T3:
                team3.remove(i)
            else:
                team2.remove(i)
    
    if set(team1) & set(team3):
        commons = set(team1).intersection(team3)
        for i in commons:
            T1 = func(list(data.keys())[0],data[list(data.keys())[0]])[i]
            T3 = func(list(data.keys())[2],data[list(data.keys())[2]])[i]
            if T3>T1:
                team1.remove(i)
            else:
                team3.remove(i)
    # previos[0] = {l: globals()[f"autoReef_{l}"] for l in previos[0]}
    # previos[1] = {l: globals()[f"autoReef_{l}"] for l in previos[1]}
    # previos[2] = {l: globals()[f"autoReef_{l}"] for l in previos[2]}
    TM1 = team1
    TM2 = team2
    TM3 = team3
    
    if func == TelePath or func == TelePathReal:
        TM1 = [name.replace('teleop', 'auto') for name in team1]
        TM2 = [name.replace('teleop', 'auto') for name in team2]
        TM3 = [name.replace('teleop', 'auto') for name in team3]
    
    TMS = TM1 + TM2 +TM3
    full_previos = previos[0] + previos[1] + previos[2]
    
    if set(TM1) & set(full_previos):
        # TM1 = TM1.remove(set(TM1).intersection(full_previos))
        TM1 = list(set(TM1) - set(full_previos))
    if set(TM2) & set(full_previos):
        # TM2 = TM2.remove(set(TM2).intersection(full_previos))
        TM2 = list(set(TM2) - set(full_previos))
    if set(TM3) & set(full_previos):
        # TM3 = TM3.remove(set(TM3).intersection(full_previos))
        TM2 = list(set(TM2) - set(full_previos))
        
    return [TM1,TM2,TM3]

# %%
data = {4635: 1, 6574: 2, 4607:3}
AutoResult = simulate(data, AutoPathReal)
print(list(data.keys())[0], ": ", AutoResult[0], "\n",
      list(data.keys())[1], ": ", AutoResult[1], "\n",
      list(data.keys())[2], ": ", AutoResult[2], "\n")
# Out:
# 4635 :  ['autoReef_topRow_nodeK']
#  6574 :  []
#  4607 :  ['autoReef_topRow_nodeD', 'autoReef_topRow_nodeC', 'autoReef_topRow_nodeE']

# %%
TeleResult = simulate(data, TelePathReal, AutoResult)
print(list(data.keys())[0], ": ", TeleResult[0], "\n",
      list(data.keys())[1], ": ", TeleResult[1], "\n",
      list(data.keys())[2], ": ", TeleResult[2], "\n")
# Out:
# 4635 :  ['autoReef_midRow_nodeK', 'autoReef_midRow_nodeJ', 'autoReef_midRow_nodeI']
#  6574 :  ['autoReef_topRow_nodeI', 'autoReef_topRow_nodeJ', 'autoReef_midRow_nodeL']
#  4607 :  ['autoReef_trough', 'autoReef_topRow_nodeA', 'autoReef_topRow_nodeB', 'autoReef_topRow_nodeC', 'autoReef_topRow_nodeD', 'autoReef_topRow_nodeE', 'autoReef_topRow_nodeH', 'autoReef_midRow_nodeA', 'autoReef_midRow_nodeB', 'autoReef_topRow_nodeF', 'autoReef_topRow_nodeL', 'autoReef_midRow_nodeD', 'autoReef_topRow_nodeK', 'autoReef_midRow_nodeC', 'autoReef_botRow_nodeB', 'autoReef_midRow_nodeE', 'autoReef_topRow_nodeG']

# %%
df
# Out:
#         comp_level  event_key  match_number  set_number  score  algaePoints  \
# 96               2          1             1           1    259         32.0
# 97               2          1             2           1    273         36.0
# 98               0          1             1           1    223         38.0
# 99               0          1            10           1    151         28.0
# 100              0          1           100           1    235         56.0
# ...            ...        ...           ...         ...    ...          ...
# 114469           1        228             1           5     64          0.0
# 114470           1        228             1           6     72          0.0
# 114471           1        228             1           7     77         32.0
# 114472           1        228             1           8     79          0.0
# 114473           1        228             1           9     61          0.0
#
# ...

# %%
#clean uselees variables
del path
del actions
del aestimated_path
del AutoResult
del i
del pos
del real_actions
del scores
del team
del TeleResult

# %%
dfc = df.copy()
succeses = []
for i in range(len(dfc)):
    print(len(dfc) - i)
    event, match, alliance, level, set_key  = dfc.iloc[i]['event_key'], dfc.iloc[i]['match_number'], dfc.iloc[i]['red'], dfc.iloc[i]['comp_level'], dfc.iloc[i]['set_number']
    real = dfc.loc[(dfc['event_key'] == event) & (dfc['match_number'] == match) & (dfc['red'] == alliance) & (dfc['comp_level'] == level) & (dfc['set_number'] == set_key)][[
        'teleopReef_trough', 'possition', 'team_number',
        'teleopReef_botRow_nodeA', 'teleopReef_botRow_nodeB', 'teleopReef_botRow_nodeC', 'teleopReef_botRow_nodeD', 'teleopReef_botRow_nodeE', 'teleopReef_botRow_nodeF',
        'teleopReef_botRow_nodeG', 'teleopReef_botRow_nodeH', 'teleopReef_botRow_nodeI', 'teleopReef_botRow_nodeJ', 'teleopReef_botRow_nodeK', 'teleopReef_botRow_nodeL',
        'teleopReef_midRow_nodeA', 'teleopReef_midRow_nodeB', 'teleopReef_midRow_nodeC', 'teleopReef_midRow_nodeD', 'teleopReef_midRow_nodeE', 'teleopReef_midRow_nodeF',
        'teleopReef_midRow_nodeG', 'teleopReef_midRow_nodeH', 'teleopReef_midRow_nodeI', 'teleopReef_midRow_nodeJ', 'teleopReef_midRow_nodeK', 'teleopReef_midRow_nodeL',
        'teleopReef_topRow_nodeA', 'teleopReef_topRow_nodeB', 'teleopReef_topRow_nodeC', 'teleopReef_topRow_nodeD', 'teleopReef_topRow_nodeE', 'teleopReef_topRow_nodeF',
        'teleopReef_topRow_nodeG', 'teleopReef_topRow_nodeH', 'teleopReef_topRow_nodeI', 'teleopReef_topRow_nodeJ', 'teleopReef_topRow_nodeK', 'teleopReef_topRow_nodeL']]
    real1 = real.iloc[0][(real.iloc[0] == True) | (real.iloc[0] > 0)]
    real2 = real.iloc[1][(real.iloc[1] == True) | (real.iloc[1] > 0)]
    real3 = real.iloc[2][(real.iloc[2] == True) | (real.iloc[2] > 0)]

    data = {real.iloc[0]['team_number']: real.iloc[0]['possition'],
            real.iloc[1]['team_number']: real.iloc[1]['possition'],
            real.iloc[2]['team_number']: real.iloc[2]['possition']}
    
    pred = simulate(data, TelePathReal)

    for j in real1:
        if j in pred[0]:
            succeses.append(1)
        else:
            succeses.append(0)
    
    for j in real2:
        if j in pred[1]:
            succeses.append(1)
        else:
            succeses.append(0)

    for j in real3:
        if j in pred[2]:
            succeses.append(1)
        else:
            succeses.append(0)


print(sum(succeses)/len(succeses))
# Out:
# 113898
# 113897
# 113896
# 113895
# 113894
# 113893
# 113892
# 113891
# 113890
# 113889
# 113888
# 113887
# 113886
# 113885
# 113884
# 113883
# 113882
# 113881
# 113880
# 113879
# 113878
# 113877
# 113876
# 113875
# 113874
# 113873
# 113872
# 113871
# 113870
# 113869
# 113868
# 113867
# 113866
# 113865
# 113864
# 113863
# 113862
# 113861
# 113860
# 113859
# 113858
# 113857
# 113856
# 113855
# 113854
# 113853
# 113852
# 113851
# 113850
# 113849
# 113848
# 113847
# 113846
# 113845
# 113844
# 113843
# 113842
# 113841
# 113840
# 113839
# 113838
# 113837
# 113836
# 113835
# 113834
# 113833
# 113832
# 113831
# 113830
# 113829
# 113828
# 113827
# 113826
# 113825
# 113824
# 113823
# 113822
# 113821
# 113820
# 113819
# 113818
# 113817
# 113816
# 113815
# 113814
# 113813
# 113812
# 113811
# 113810
# 113809
# 113808
# 113807
# 113806
# 113805
# 113804
# 113803
# 113802
# 113801
# 113800
# 113799
# 113798
# 113797
# 113796
# 113795
# 113794
# 113793
# 113792
# 113791
# 113790
# 113789
# 113788
# ...

# %%
data
# Out:
# {2486: 1, 498: 3}

# %%
real
# Out:
#        teleopReef_trough  possition  team_number  teleopReef_botRow_nodeA  \
# 708                  0.0          1         2486                    False
# 19787                0.0          2          498                    False
# 38866                0.0          3          498                    False
#
#        teleopReef_botRow_nodeB  teleopReef_botRow_nodeC  \
# 708                       True                     True
# 19787                     True                     True
# 38866                     True                     True
#
#        teleopReef_botRow_nodeD  teleopReef_botRow_nodeE  \
# 708                       True                    False
# 19787                     True                    False
# 38866                     True                    False
#
#        teleopReef_botRow_nodeF  teleopReef_botRow_nodeG  ...  \
# 708                      False                    False  ...
# 19787                    False                    False  ...
# ...

# %%
dfc['match_number'].value_counts()
# Out:
# match_number
# 1      19752
# 2       2634
# 3       1590
# 4       1362
# 12      1344
#        ...
# 121       48
# 122       48
# 123       48
# 126        6
# 127        6
# Name: count, Length: 127, dtype: int64

# %%
dfc[['event_key', 'match_number']].value_counts()
# Out:
# event_key  match_number
# 2025alhu   1               90
# 2025ctgla  1               90
# 2025cnsh   1               90
# 2025txcle  1               90
# 2025code   1               90
#                            ..
# 2025mdsev  53               6
#            54               6
#            55               6
#            56               6
# 2025xxmel  57               6
# Name: count, Length: 15764, dtype: int64

# %%
data = {2783: 1, 51: 2, 4907:3}
result = simulate(data, AutoPathReal)
print(list(data.keys())[0], ": ", result[0], "\n",
      list(data.keys())[1], ": ", result[1], "\n",
      list(data.keys())[2], ": ", result[2], "\n")
# Out:
# 2783 :  ['autoReef_topRow_nodeI', 'autoReef_topRow_nodeL']
#  51 :  ['autoReef_topRow_nodeH']
#  4907 :  ['autoReef_topRow_nodeE', 'autoReef_topRow_nodeC', 'autoReef_topRow_nodeD']

# %% [markdown]
# dis3 - 54
# Hopper - 15

# %%
sns.countplot(data = df.loc[df['team_number'] == 1574], x = 'win')
# Out:
# <Axes: xlabel='win', ylabel='count'>

# %%
sns.countplot(data = df.loc[df['team_number'] == 1323], x = 'win')
# Out:
# <Axes: xlabel='win', ylabel='count'>

# %%
df
# Out:
#         comp_level  event_key  match_number  set_number  score  algaePoints  \
# 0                2   2025alhu             1           1    124         32.0
# 1                2   2025alhu             2           1    144         28.0
# 2                0   2025alhu             1           1    129         28.0
# 3                0   2025alhu            10           1    118          8.0
# 4                0   2025alhu            11           1     67         14.0
# ...            ...        ...           ...         ...    ...          ...
# 114469           1  2025xxmel             1           5     64          0.0
# 114470           1  2025xxmel             1           6     72          0.0
# 114471           1  2025xxmel             1           7     77         32.0
# 114472           1  2025xxmel             1           8     79          0.0
# 114473           1  2025xxmel             1           9     61          0.0
#
# ...

# %%
# tele_path = estimate_path(TelePath(1574,2))
# tele_nodes = set([item.split('_', 1)[1] for item in tele_path if '_' in item])
# tele_trail = [brench for brench in tele_nodes if brench not in tele_nodes]
# tele_trail

# %%
end_time = time.time()
print(end_time - start_time)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 end_time = time.time()
#       2 print(end_time - start_time)
#
# NameError: name 'time' is not defined
