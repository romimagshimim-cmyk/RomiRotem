# %%
import pandas as pd
import time
import re

# %%
path = r'C:\Users\progr\OneDrive\Desktop\Project_Statbotics\full_table2.csv'

df = pd.read_csv(path)

# %%
#delete
#actual_time, event_key, post_result_time, time, videos,

# %%
df
# Out:
#          actual_time comp_level event_key             key  match_number  \
# 0       1.742056e+09          f  2025alhu   2025alhu_f1m1             1
# 1       1.742058e+09          f  2025alhu   2025alhu_f1m2             2
# 2       1.741960e+09         qm  2025alhu    2025alhu_qm1             1
# 3       1.741965e+09         qm  2025alhu   2025alhu_qm10            10
# 4       1.741965e+09         qm  2025alhu   2025alhu_qm11            11
# ...              ...        ...       ...             ...           ...
# 111439  1.749930e+09         sf  2025wiwi  2025wiwi_sf5m1             1
# 111440  1.749931e+09         sf  2025wiwi  2025wiwi_sf6m1             1
# 111441  1.749931e+09         sf  2025wiwi  2025wiwi_sf7m1             1
# 111442  1.749932e+09         sf  2025wiwi  2025wiwi_sf8m1             1
# 111443  1.749933e+09         sf  2025wiwi  2025wiwi_sf9m1             1
#
#         post_result_time  set_number        time  \
# 0           1.742056e+09           1  1742055840
# 1           1.742058e+09           1  1742057100
# 2           1.741960e+09           1  1741960200
# 3           1.741965e+09           1  1741965000
# 4           1.741965e+09           1  1741965480
# ...                  ...         ...         ...
# 111439      1.749930e+09           5  1749928800
# 111440      1.749931e+09           6  1749929400
# 111441      1.749931e+09           7  1749930000
# 111442      1.749932e+09           8  1749930600
# 111443      1.749933e+09           9  1749931200
#
#                                              videos winning_alliance  ...  \
# 0       [{'key': 'NSWVoO4ZDEs', 'type': 'youtube'}]             blue  ...
# 1       [{'key': '1FpcfKgS3kw', 'type': 'youtube'}]             blue  ...
# 2       [{'key': 'mAbsfvQlhaw', 'type': 'youtube'}]              red  ...
# 3       [{'key': 'xrkAU-qZY-E', 'type': 'youtube'}]              red  ...
# 4       [{'key': 'ae-lJ4geVPg', 'type': 'youtube'}]             blue  ...
# ...                                             ...              ...  ...
# 111439  [{'key': 'tsHBY8tak-Y', 'type': 'youtube'}]             blue  ...
# 111440  [{'key': 'jhFDvgGOHh0', 'type': 'youtube'}]             blue  ...
# 111441  [{'key': 'gs12RD28JaU', 'type': 'youtube'}]              red  ...
# 111442  [{'key': 'R2HdxFi6Pko', 'type': 'youtube'}]             blue  ...
# 111443  [{'key': '4EDH-FVSSak', 'type': 'youtube'}]             blue  ...
#
#         teleopReef_topRow_nodeI  teleopReef_topRow_nodeJ  \
# 0                          True                    False
# 1                          True                     True
# 2                         False                    False
# 3                          True                     True
# 4                         False                     True
# ...                         ...                      ...
# 111439                    False                    False
# 111440                    False                    False
# 111441                     True                     True
# 111442                     True                     True
# 111443                    False                     True
#
#         teleopReef_topRow_nodeK  teleopReef_topRow_nodeL  teleopReef_trough  \
# 0                         False                     True                0.0
# 1                          True                    False                0.0
# 2                         False                    False                5.0
# 3                          True                     True                1.0
# 4                          True                     True                1.0
# ...                         ...                      ...                ...
# 111439                    False                    False                0.0
# 111440                    False                     True                2.0
# 111441                     True                     True                5.0
# 111442                     True                     True                0.0
# 111443                     True                     True                3.0
#
#         wallAlgaeCount team_number  scorePenaltyFree  possition  alliance
# 0                  0.0     frc2783             124.0          1       red
# 1                  0.0     frc2783             144.0          1       red
# 2                  2.0     frc5045             129.0          1       red
# 3                  0.0      frc538             112.0          1       red
# 4                  1.0     frc6107              61.0          1       red
# ...                ...         ...               ...        ...       ...
# 111439             0.0      frc155               1.0          3      blue
# 111440             3.0      frc230              90.0          3      blue
# 111441             0.0     frc8085             101.0          3      blue
# 111442             2.0     frc7869             135.0          3      blue
# 111443             4.0      frc230             128.0          3      blue
#
# [111444 rows x 121 columns]

# %%
df.drop(['actual_time', 'key', 'post_result_time', 'time', 'videos'], axis=1, inplace=True)

# %%
df
# Out:
#        comp_level event_key  match_number  set_number winning_alliance  score  \
# 0               f  2025alhu             1           1             blue    124
# 1               f  2025alhu             2           1             blue    144
# 2              qm  2025alhu             1           1              red    129
# 3              qm  2025alhu            10           1              red    118
# 4              qm  2025alhu            11           1             blue     67
# ...           ...       ...           ...         ...              ...    ...
# 111439         sf  2025wiwi             1           5             blue      1
# 111440         sf  2025wiwi             1           6             blue     90
# 111441         sf  2025wiwi             1           7              red    107
# 111442         sf  2025wiwi             1           8             blue    147
# 111443         sf  2025wiwi             1           9             blue    128
#
#         adjustPoints  algaePoints  autoBonusAchieved  autoCoralCount  ...  \
# 0                0.0         32.0              False             4.0  ...
# 1                0.0         28.0              False             3.0  ...
# 2                0.0         28.0              False             3.0  ...
# 3                0.0          8.0               True             3.0  ...
# 4                0.0         14.0              False             1.0  ...
# ...              ...          ...                ...             ...  ...
# 111439           1.0          0.0              False             0.0  ...
# 111440           0.0         34.0              False             1.0  ...
# 111441           0.0          0.0              False             2.0  ...
# 111442           0.0         12.0              False             1.0  ...
# 111443           0.0         40.0              False             1.0  ...
#
#         teleopReef_topRow_nodeI teleopReef_topRow_nodeJ  \
# 0                          True                   False
# 1                          True                    True
# 2                         False                   False
# 3                          True                    True
# 4                         False                    True
# ...                         ...                     ...
# 111439                    False                   False
# 111440                    False                   False
# 111441                     True                    True
# 111442                     True                    True
# 111443                    False                    True
#
#         teleopReef_topRow_nodeK  teleopReef_topRow_nodeL  teleopReef_trough  \
# 0                         False                     True                0.0
# 1                          True                    False                0.0
# 2                         False                    False                5.0
# 3                          True                     True                1.0
# 4                          True                     True                1.0
# ...                         ...                      ...                ...
# 111439                    False                    False                0.0
# 111440                    False                     True                2.0
# 111441                     True                     True                5.0
# 111442                     True                     True                0.0
# 111443                     True                     True                3.0
#
#         wallAlgaeCount  team_number  scorePenaltyFree  possition  alliance
# 0                  0.0      frc2783             124.0          1       red
# 1                  0.0      frc2783             144.0          1       red
# 2                  2.0      frc5045             129.0          1       red
# 3                  0.0       frc538             112.0          1       red
# 4                  1.0      frc6107              61.0          1       red
# ...                ...          ...               ...        ...       ...
# 111439             0.0       frc155               1.0          3      blue
# 111440             3.0       frc230              90.0          3      blue
# 111441             0.0      frc8085             101.0          3      blue
# 111442             2.0      frc7869             135.0          3      blue
# 111443             4.0       frc230             128.0          3      blue
#
# [111444 rows x 116 columns]

# %%
#change
#endGame, team_number, alliance, comp_level, event_key, winning_alliance, autoLine

# %%
df['endGame'].unique()
# Out:
# array(['Parked', 'DeepCage', 'Nothing', 'ShallowCage'], dtype=object)

# %%
df['endGame'] = df['endGame'].map({'Nothing': 0, 'Parked': 1, 'ShallowCage': 2, 'DeepCage': 3})

# %%
df['red'] = df['alliance'] == 'red'
df['blue'] = df['alliance'] == 'blue'

# %%
df['winning_red'] = df['winning_alliance'] == 'red'
df['winning_blue'] = df['winning_alliance'] == 'blue'

# %%
df.drop(['alliance', 'winning_alliance'], axis = 1, inplace = True)

# %%
df['team_number'] = df['team_number'].map(lambda x: int(re.search(r'\d+', x).group()))

# %%
df['comp_level'].unique()
# Out:
# array(['f', 'qm', 'sf'], dtype=object)

# %%
df['comp_level'] = df['comp_level'].map({'qm': 0, 'sf': 1, 'f': 2})

# %%
df['event_key'] = pd.factorize(df['event_key'])[0]

# %%
df['autoLine'] = df['autoLine'].map({'Yes': True, 'No': False})

# %%
df
# Out:
#         comp_level  event_key  match_number  set_number  score  adjustPoints  \
# 0                2          0             1           1    124           0.0
# 1                2          0             2           1    144           0.0
# 2                0          0             1           1    129           0.0
# 3                0          0            10           1    118           0.0
# 4                0          0            11           1     67           0.0
# ...            ...        ...           ...         ...    ...           ...
# 111439           1        219             1           5      1           1.0
# 111440           1        219             1           6     90           0.0
# 111441           1        219             1           7    107           0.0
# 111442           1        219             1           8    147           0.0
# 111443           1        219             1           9    128           0.0
#
#         algaePoints  autoBonusAchieved  autoCoralCount  autoCoralPoints  ...  \
# 0              32.0              False             4.0             28.0  ...
# 1              28.0              False             3.0             21.0  ...
# 2              28.0              False             3.0             21.0  ...
# 3               8.0               True             3.0             21.0  ...
# 4              14.0              False             1.0              3.0  ...
# ...             ...                ...             ...              ...  ...
# 111439          0.0              False             0.0              0.0  ...
# 111440         34.0              False             1.0              7.0  ...
# 111441          0.0              False             2.0             14.0  ...
# 111442         12.0              False             1.0              7.0  ...
# 111443         40.0              False             1.0              7.0  ...
#
#         teleopReef_topRow_nodeL  teleopReef_trough  wallAlgaeCount  \
# 0                          True                0.0             0.0
# 1                         False                0.0             0.0
# 2                         False                5.0             2.0
# 3                          True                1.0             0.0
# 4                          True                1.0             1.0
# ...                         ...                ...             ...
# 111439                    False                0.0             0.0
# 111440                     True                2.0             3.0
# 111441                     True                5.0             0.0
# 111442                     True                0.0             2.0
# 111443                     True                3.0             4.0
#
#         team_number  scorePenaltyFree  possition    red   blue  winning_red  \
# 0              2783             124.0          1   True  False        False
# 1              2783             144.0          1   True  False        False
# 2              5045             129.0          1   True  False         True
# 3               538             112.0          1   True  False         True
# 4              6107              61.0          1   True  False        False
# ...             ...               ...        ...    ...    ...          ...
# 111439          155               1.0          3  False   True        False
# 111440          230              90.0          3  False   True        False
# 111441         8085             101.0          3  False   True         True
# 111442         7869             135.0          3  False   True        False
# 111443          230             128.0          3  False   True        False
#
#         winning_blue
# 0               True
# 1               True
# 2              False
# 3              False
# 4               True
# ...              ...
# 111439          True
# 111440          True
# 111441         False
# 111442          True
# 111443          True
#
# [111444 rows x 118 columns]

# %%
df_info = pd.DataFrame({
    'column': df.columns,
    'non_nulls': df.notnull().sum(),
    'dtype': df.dtypes
}).reset_index(drop=True)

# %%
df_info['dtype'].unique()
# Out:
# array([dtype('int64'), dtype('float64'), dtype('bool')], dtype=object)

# %%
df['win'] = ((df['blue'] & df['winning_blue']) | (df['red'] & df['winning_red']))

# %%
df
# Out:
#         comp_level  event_key  match_number  set_number  score  adjustPoints  \
# 0                2          0             1           1    124           0.0
# 1                2          0             2           1    144           0.0
# 2                0          0             1           1    129           0.0
# 3                0          0            10           1    118           0.0
# 4                0          0            11           1     67           0.0
# ...            ...        ...           ...         ...    ...           ...
# 111439           1        219             1           5      1           1.0
# 111440           1        219             1           6     90           0.0
# 111441           1        219             1           7    107           0.0
# 111442           1        219             1           8    147           0.0
# 111443           1        219             1           9    128           0.0
#
#         algaePoints  autoBonusAchieved  autoCoralCount  autoCoralPoints  ...  \
# 0              32.0              False             4.0             28.0  ...
# 1              28.0              False             3.0             21.0  ...
# 2              28.0              False             3.0             21.0  ...
# 3               8.0               True             3.0             21.0  ...
# 4              14.0              False             1.0              3.0  ...
# ...             ...                ...             ...              ...  ...
# 111439          0.0              False             0.0              0.0  ...
# 111440         34.0              False             1.0              7.0  ...
# 111441          0.0              False             2.0             14.0  ...
# 111442         12.0              False             1.0              7.0  ...
# 111443         40.0              False             1.0              7.0  ...
#
#         teleopReef_trough  wallAlgaeCount  team_number  scorePenaltyFree  \
# 0                     0.0             0.0         2783             124.0
# 1                     0.0             0.0         2783             144.0
# 2                     5.0             2.0         5045             129.0
# 3                     1.0             0.0          538             112.0
# 4                     1.0             1.0         6107              61.0
# ...                   ...             ...          ...               ...
# 111439                0.0             0.0          155               1.0
# 111440                2.0             3.0          230              90.0
# 111441                5.0             0.0         8085             101.0
# 111442                0.0             2.0         7869             135.0
# 111443                3.0             4.0          230             128.0
#
#         possition    red   blue  winning_red  winning_blue    win
# 0               1   True  False        False          True  False
# 1               1   True  False        False          True  False
# 2               1   True  False         True         False   True
# 3               1   True  False         True         False   True
# 4               1   True  False        False          True  False
# ...           ...    ...    ...          ...           ...    ...
# 111439          3  False   True        False          True   True
# 111440          3  False   True        False          True   True
# 111441          3  False   True         True         False  False
# 111442          3  False   True        False          True   True
# 111443          3  False   True        False          True   True
#
# [111444 rows x 119 columns]

# %%
df.to_csv('final_table.csv', index=False)
