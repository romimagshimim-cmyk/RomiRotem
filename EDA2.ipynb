# %%
import requests
import json
import pandas as pd
import seaborn as sns
import matplotlib as plt
import time
import numpy as np

# %%
path = r'C:\Users\Magsihim_AI\Desktop\Project_Statbotics\full_table2.csv'

df = pd.read_csv(path)

# %%
df
# Out:
#          actual_time comp_level  event_key              key  match_number  \
# 0       1.742056e+09          f   2025alhu    2025alhu_f1m1             1
# 1       1.742058e+09          f   2025alhu    2025alhu_f1m2             2
# 2       1.741960e+09         qm   2025alhu     2025alhu_qm1             1
# 3       1.741965e+09         qm   2025alhu    2025alhu_qm10            10
# 4       1.741965e+09         qm   2025alhu    2025alhu_qm11            11
# ...              ...        ...        ...              ...           ...
# 114469  1.752379e+09         sf  2025xxmel  2025xxmel_sf5m1             1
# 114470  1.752379e+09         sf  2025xxmel  2025xxmel_sf6m1             1
# 114471  1.752380e+09         sf  2025xxmel  2025xxmel_sf7m1             1
# 114472  1.752380e+09         sf  2025xxmel  2025xxmel_sf8m1             1
# 114473  1.752381e+09         sf  2025xxmel  2025xxmel_sf9m1             1
#
#         post_result_time  set_number          time  \
# ...

# %%
sns.histplot(data = df, x = 'scorePenaltyFree', kde = True)
# Out:
# <Axes: xlabel='scorePenaltyFree', ylabel='Count'>

# %%
sns.countplot(data = df, x = 'alliance').bar_label(sns.countplot(x='alliance', data=df).containers[0])
# Out:
# [Text(0, 0, '57237'), Text(0, 0, '57237')]

# %%
sns.histplot(data = df, x = 'algaePoints', kde = True)
# Out:
# <Axes: xlabel='algaePoints', ylabel='Count'>

# %%
sns.histplot(data = df, x = 'autoPoints', kde = True)
# Out:
# <Axes: xlabel='autoPoints', ylabel='Count'>

# %%
sns.histplot(data = df, x = 'autoPoints', kde = True, bins = 23)
# Out:
# <Axes: xlabel='autoPoints', ylabel='Count'>

# %%
pd.set_option('display.max_info_columns', 240)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 114474 entries, 0 to 114473
# Data columns (total 121 columns):
#  #    Column                      Non-Null Count   Dtype
# ---   ------                      --------------   -----
#  0    actual_time                 114474 non-null  float64
#  1    comp_level                  114474 non-null  object
#  2    event_key                   114474 non-null  object
#  3    key                         114474 non-null  object
#  4    match_number                114474 non-null  int64
#  5    post_result_time            114474 non-null  float64
#  6    set_number                  114474 non-null  int64
#  7    time                        114474 non-null  float64
#  8    videos                      114474 non-null  object
#  9    winning_alliance            114474 non-null  object
#  10   score                       114474 non-null  int64
#  11   adjustPoints                114474 non-null  float64
# ...

# %%
df.iloc[708]
# Out:
# actual_time            1755995544.0
# comp_level                       sf
# event_key                 2025azrl4
# key                 2025azrl4_sf4m1
# match_number                      1
#                          ...
# wallAlgaeCount                  0.0
# team_number                 frc2486
# scorePenaltyFree              128.0
# possition                         1
# alliance                        red
# Name: 708, Length: 121, dtype: object

# %%
df.loc[(df['scorePenaltyFree'] == 128) & (df['key'] == '2025azrl4_sf4m1') & (df['comp_level'] == 'sf') & (df['match_number'] == 1)]
# Out:
#         actual_time comp_level  event_key              key  match_number  \
# 708    1.755996e+09         sf  2025azrl4  2025azrl4_sf4m1             1
# 19787  1.755996e+09         sf  2025azrl4  2025azrl4_sf4m1             1
# 38866  1.755996e+09         sf  2025azrl4  2025azrl4_sf4m1             1
#
#        post_result_time  set_number          time  \
# 708        1.755996e+09           4  1.755995e+09
# 19787      1.755996e+09           4  1.755995e+09
# 38866      1.755996e+09           4  1.755995e+09
#
#                                             videos winning_alliance  ...  \
# 708    [{'key': 'f09IwCRooFs', 'type': 'youtube'}]              red  ...
# 19787  [{'key': 'f09IwCRooFs', 'type': 'youtube'}]              red  ...
# 38866  [{'key': 'f09IwCRooFs', 'type': 'youtube'}]              red  ...
#
#        teleopReef_topRow_nodeI  teleopReef_topRow_nodeJ  \
# 708                       True                     True
# 19787                     True                     True
# ...

# %%
df.iloc[601]
# Out:
# actual_time           1748726540.0
# comp_level                      qm
# event_key                2025azrl1
# key                 2025azrl1_qm18
# match_number                    18
#                          ...
# wallAlgaeCount                 0.0
# team_number                frc2486
# scorePenaltyFree             120.0
# possition                        1
# alliance                       red
# Name: 601, Length: 121, dtype: object

# %%
df.head(1)
# Out:
#     actual_time comp_level event_key            key  match_number  \
# 0  1.742056e+09          f  2025alhu  2025alhu_f1m1             1
#
#    post_result_time  set_number          time  \
# 0      1.742056e+09           1  1.742056e+09
#
#                                         videos winning_alliance  ...  \
# 0  [{'key': 'NSWVoO4ZDEs', 'type': 'youtube'}]             blue  ...
#
#    teleopReef_topRow_nodeI  teleopReef_topRow_nodeJ  teleopReef_topRow_nodeK  \
# 0                     True                    False                    False
#
#    teleopReef_topRow_nodeL  teleopReef_trough  wallAlgaeCount team_number  \
# 0                     True                0.0             0.0     frc2783
#
#    scorePenaltyFree  possition  alliance
# 0             124.0          1       red
#
# [1 rows x 121 columns]

# %%
sns.countplot(data = df, x = 'endGame')
# Out:
# <Axes: xlabel='endGame', ylabel='count'>
